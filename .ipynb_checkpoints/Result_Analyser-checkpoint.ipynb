# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define path
path = "/Users/joche/Documents/Github/Score-driven_Tensor_Factor_Model/"

# %%
# Read in all data
df_2_5 = pd.read_excel(path+"Simulation_Results_K=1_d1=5_Check.xlsx",index_col=0)


# Show all 4 boxplots
show_boxplot(data_a=[df_2_5.iloc[:,0], [1], [0.5]],
             data_b=[df_2_5.iloc[:,1], [1], [0.1]],
             ticks=['K=1', 'K=2', 'K=3'],
             label_a='RMSE first factor',
             label_b='Average RMSE all factors')

# %%
# Define method plotting the boxplot
def show_boxplot(data_a,data_b,ticks,label_a,label_b):

    # Set the colors
    def set_box_color(bp, color):
        plt.setp(bp['boxes'], color=color)
        plt.setp(bp['whiskers'], color=color)
        plt.setp(bp['caps'], color=color)
        plt.setp(bp['medians'], color=color)

    plt.figure(figsize=(7, 4))
    plt.grid(which='major', axis='y', color='#DDDDDD', linestyle=':', linewidth=1.0)

    bpl = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0-0.3, widths=0.5,flierprops={'marker': 'o', 'markersize': 5, 'mec': 'navy'})
    bpr = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0+0.3, widths=0.5,flierprops={'marker': 'o', 'markersize': 5, 'mec': 'orangered'})
    set_box_color(bpl, 'navy')
    set_box_color(bpr, 'orangered')

    plt.plot([], c='navy', label=label_a)
    plt.plot([], c='orangered', label=label_b)
    plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", mode="expand", borderaxespad=0, ncol=2)

    plt.xticks(range(0, len(ticks) * 2, 2), ticks)
    plt.xlim(-1, len(ticks)*2-1)
    plt.ylim(0, 1.5)
    plt.tight_layout()
    plt.show()

# %%
np.random.seed(19680801)
fruit_weights = [
    np.random.normal(130, 10, size=100),
    np.random.normal(125, 20, size=100),
    np.random.normal(120, 30, size=100),
]
labels = ['peaches', 'oranges', 'tomatoes']
colors = ['peachpuff', 'orange', 'tomato']

fig, ax = plt.subplots()
ax.set_ylabel('fruit weight (g)')

bplot = ax.boxplot(fruit_weights,
                   patch_artist=True,  # fill with color
                   tick_labels=labels)  # will be used to label x-ticks

# fill with colors
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 13
#      10 fig, ax = plt.subplots()
#      11 ax.set_ylabel('fruit weight (g)')
# ---> 13 bplot = ax.boxplot(fruit_weights,
#      14                    patch_artist=True,  # fill with color
#      15                    tick_labels=labels)  # will be used to label x-ticks
#      17 # fill with colors
#      18 for patch, color in zip(bplot['boxes'], colors):
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# TypeError: boxplot() got an unexpected keyword argument 'tick_labels'
